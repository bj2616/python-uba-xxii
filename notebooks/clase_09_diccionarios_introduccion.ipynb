# %% [markdown]
# # Clase 09 — Diccionarios (introducción)**Curso:** Introducción a la Programación con Python — UBA XXII**Fecha:** _(completar)_**Objetivo:** Asociar claves con valores y realizar consultas.**Contenidos:** Creación y consulta de diccionarios.**Ejercicio principal:** Ingresar el tipo de nube observada (texto) y obtener la altura correspondiente mediante un diccionario.

# %%
# Código de alumnonombre = input("Ingrese su nombre: ")print(f"¡Bienvenido/a, {nombre}!")

# %% [markdown]
# ## Desarrollo

# %%
# Escribir acá el desarrollo de la clase

# %% [markdown]
# ## Resumen de la clase_(1 o 2 oraciones para completar en la planilla de asistencia)_
