# %% [markdown]
# # Clase 03 — Operadores y expresiones**Curso:** Introducción a la Programación con Python — UBA XXII**Fecha:** _(completar)_**Objetivo:** Operar con variables y mostrar resultados formateados.**Contenidos:** Operadores aritméticos y de comparación, formateo de print().**Ejercicio principal:** Calcular el % de asistencia del curso según datos reales.

# %%
# Código de alumnonombre = input("Ingrese su nombre: ")print(f"¡Bienvenido/a, {nombre}!")

# %% [markdown]
# ## Desarrollo

# %%
# Escribir acá el desarrollo de la clase

# %% [markdown]
# ## Resumen de la clase_(1 o 2 oraciones para completar en la planilla de asistencia)_
