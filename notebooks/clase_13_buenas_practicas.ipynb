# %% [markdown]
# # Clase 13 — Buenas prácticas**Curso:** Introducción a la Programación con Python — UBA XXII**Fecha:** _(completar)_**Objetivo:** Escribir código claro y mantenible.**Contenidos:** Nombres de variables, comentarios, funciones cortas, evitar repetición.**Ejercicio principal:** Repasar y refactorizar ejercicios anteriores aplicando buenas prácticas.

# %%
# Código de alumnonombre = input("Ingrese su nombre: ")print(f"¡Bienvenido/a, {nombre}!")

# %% [markdown]
# ## Desarrollo

# %%
# Escribir acá el desarrollo de la clase

# %% [markdown]
# ## Resumen de la clase_(1 o 2 oraciones para completar en la planilla de asistencia)_
