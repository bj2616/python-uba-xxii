# %% [markdown]
# # Clase 08 — Listas**Curso:** Introducción a la Programación con Python — UBA XXII**Fecha:** _(completar)_**Objetivo:** Almacenar y manipular colecciones de datos.**Contenidos:** Crear, indexar, recorrer y agregar elementos a una lista.**Ejercicio principal:** Cargar una lista de datos del curso y operar sobre ella.

# %%
# Código de alumnonombre = input("Ingrese su nombre: ")print(f"¡Bienvenido/a, {nombre}!")

# %% [markdown]
# ## Desarrollo

# %%
# Escribir acá el desarrollo de la clase

# %% [markdown]
# ## Resumen de la clase_(1 o 2 oraciones para completar en la planilla de asistencia)_
