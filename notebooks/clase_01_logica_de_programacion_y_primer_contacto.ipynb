# %% [markdown]
# # Clase 01 — Lógica de programación y primer contacto**Curso:** Introducción a la Programación con Python — UBA XXII**Fecha:** _(completar)_**Objetivo:** Comprender qué es programar y familiarizarse con el entorno de trabajo.**Contenidos:** Entorno de trabajo, la función print(), primer programa.**Ejercicio principal:** Escribir un programa que salude e imprima el nombre del curso.

# %%
# Código de alumnonombre = input("Ingrese su nombre: ")print(f"¡Bienvenido/a, {nombre}!")

# %% [markdown]
# ## Desarrollo

# %%
# Escribir acá el desarrollo de la clase

# %% [markdown]
# ## Resumen de la clase_(1 o 2 oraciones para completar en la planilla de asistencia)_
