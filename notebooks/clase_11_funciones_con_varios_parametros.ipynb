# %% [markdown]
# # Clase 11 — Funciones con varios parámetros**Curso:** Introducción a la Programación con Python — UBA XXII**Fecha:** _(completar)_**Objetivo:** Trabajar con funciones más complejas.**Contenidos:** Funciones con múltiples parámetros.**Ejercicio principal:** Calcular los puntos de un equipo en el Mundial 2026 según resultados (ganado/empatado/perdido).

# %%
# Código de alumnonombre = input("Ingrese su nombre: ")print(f"¡Bienvenido/a, {nombre}!")

# %% [markdown]
# ## Desarrollo

# %%
# Escribir acá el desarrollo de la clase

# %% [markdown]
# ## Resumen de la clase_(1 o 2 oraciones para completar en la planilla de asistencia)_
