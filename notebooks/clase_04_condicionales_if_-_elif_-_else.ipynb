# %% [markdown]
# # Clase 04 — Condicionales (if / elif / else)**Curso:** Introducción a la Programación con Python — UBA XXII**Fecha:** _(completar)_**Objetivo:** Tomar decisiones dentro de un programa según condiciones.**Contenidos:** Estructuras if, elif, else.**Ejercicio principal:** Estimar la probabilidad de requisa en el módulo y pabellón, según datos aportados por el curso.

# %%
# Código de alumnonombre = input("Ingrese su nombre: ")print(f"¡Bienvenido/a, {nombre}!")

# %% [markdown]
# ## Desarrollo

# %%
# Escribir acá el desarrollo de la clase

# %% [markdown]
# ## Resumen de la clase_(1 o 2 oraciones para completar en la planilla de asistencia)_
