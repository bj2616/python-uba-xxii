# %% [markdown]
# # Clase 15 — Diseño del proyecto final**Curso:** Introducción a la Programación con Python — UBA XXII**Fecha:** _(completar)_**Objetivo:** Planificar el proyecto final antes de programarlo.**Contenidos:** Diseño de funciones y variables necesarias para el juego de penales.**Ejercicio principal:** Esquematizar en papel/código las funciones necesarias para el juego final.

# %%
# Código de alumnonombre = input("Ingrese su nombre: ")print(f"¡Bienvenido/a, {nombre}!")

# %% [markdown]
# ## Desarrollo

# %%
# Escribir acá el desarrollo de la clase

# %% [markdown]
# ## Resumen de la clase_(1 o 2 oraciones para completar en la planilla de asistencia)_
