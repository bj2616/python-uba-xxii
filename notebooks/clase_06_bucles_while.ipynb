# %% [markdown]
# # Clase 06 — Bucles while**Curso:** Introducción a la Programación con Python — UBA XXII**Fecha:** _(completar)_**Objetivo:** Repetir acciones hasta que se cumpla una condición de corte.**Contenidos:** Estructura while, acumuladores.**Ejercicio principal:** Simular la compra de paquetes de una figurita hasta completar un álbum de 6.

# %%
# Código de alumnonombre = input("Ingrese su nombre: ")print(f"¡Bienvenido/a, {nombre}!")

# %% [markdown]
# ## Desarrollo

# %%
# Escribir acá el desarrollo de la clase

# %% [markdown]
# ## Resumen de la clase_(1 o 2 oraciones para completar en la planilla de asistencia)_
