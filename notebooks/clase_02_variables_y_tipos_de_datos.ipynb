# %% [markdown]
# # Clase 02 — Variables y tipos de datos**Curso:** Introducción a la Programación con Python — UBA XXII**Fecha:** _(completar)_**Objetivo:** Conocer los tipos de datos básicos y aprender a pedir datos al usuario.**Contenidos:** int, float, str, bool. Uso de input().**Ejercicio principal:** Pedir el nombre del alumno con input() para generar su 'código de alumno'.

# %%
# Código de alumnonombre = input("Ingrese su nombre: ")print(f"¡Bienvenido/a, {nombre}!")

# %% [markdown]
# ## Desarrollo

# %%
# Escribir acá el desarrollo de la clase

# %% [markdown]
# ## Resumen de la clase_(1 o 2 oraciones para completar en la planilla de asistencia)_
